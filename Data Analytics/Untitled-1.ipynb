# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("from hotels and home stays (Responses) (1).xlsx")

# %%
df.head()
# Out:
#                 Timestamp What type of business do you operate?  \
# 0 2025-07-25 15:21:17.282                              Homestay
# 1 2025-08-01 12:26:17.151                              Homestay
# 2 2025-08-01 12:28:45.021                            Restaurant
# 3 2025-08-01 12:32:02.602                                  Both
# 4 2025-08-01 12:34:34.989                              Homestay
#
#   How long has your business been running?  \
# 0                               4–10 years
# 1                               4–10 years
# 2                               4–10 years
# 3                                 35 years
# 4                               4–10 years
#
#   What is the ownership type of your business?\n   \
# 0                             Sole proprietorship
# 1                                    Family-owned
# 2                                     Partnership
# 3                                    Family-owned
# 4                             Sole proprietorship
#
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'What type of business do you operate?',
#        'How long has your business been running?',
#        'What is the ownership type of your business?\n ',
#        'How many staff members are currently employed?',
#        'What percentage of your customers are tourists?',
#        'Which type of tourists do you mostly cater to?',
#        'What is the main tourist season for your business?',
#        'What is the most common reason tourists visit your establishment?',
#        'How do tourists find your establishment?',
#        'Which platform brings you the most tourist traffic?',
#        'Has your revenue increased due to tourism?',
#        'What percentage of income is generated from tourists?',
#        'Has employment in your business grown due to tourism?',
#        'Do you use local products/services to serve tourists?',
#        'Has tourism created job opportunities in your locality?',
#        'What is your peak revenue period?',
# ...

# %%
df.drop("Timestamp",axis=1, inplace=True)

# %%
df["What type of business do you operate?"].unique()
# Out:
# array(['Homestay', 'Restaurant', 'Both'], dtype=object)

# %%
for i in df:
    print(i)
    print(df[i].unique())
# Out:
# What type of business do you operate?
# ['Homestay' 'Restaurant' 'Both']
# How long has your business been running?
# ['4–10 years' '35 years' 'More than 10 years' '1–3 years'
#  'Less than 1 year']
# What is the ownership type of your business?
#
# ['Sole proprietorship' 'Family-owned' 'Partnership' 'Other']
# How many staff members are currently employed?
# ['1–5' '6–10' 'More than 20' '11–20']
# What percentage of your customers are tourists?
# ['51–75%' '76–100%' '26–50%' '0–25%']
# Which type of tourists do you mostly cater to?
# ['International' 'Both equally' 'Domestic' 'Not sure']
# What is the main tourist season for your business?
# ['October–January' 'Business is steady year-round' 'February–May'
#  'June–September']
# What is the most common reason tourists visit your establishment?
# ['Location' 'Authentic food/stay' 'Travel packages' 'Online reviews']
# How do tourists find your establishment?
# ['Travel agents' 'Online platforms' 'Local recommendations' 'Walk-in']
# ...
